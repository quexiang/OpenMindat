# %% [markdown]
# This Notebook mainly shows how to retrieve geomaterials records based on multiple properties. Here we need to retrieve records of the IMA-approved minerals, containing lithium (Li) and oxygen (O) elements, with Mohs hardness between 5.8 and 6, and have a triclinic crystal structure.

# %%
library(httr)
library(jsonlite)
library (OpenMindat)

# %% [markdown]
# Initialize OpenMindat

# %%
#Please replace the following string “9ce67655d74bcd981e937be80dcea9cb” with your Mindat token.
mindat_connection("9ce67655d74bcd981e937be80dcea9cb",page_size = 1500)

# %% [markdown]
# Here we use a base query function (i.e.  “geomaterials_contain_all_elems”) and add some additional fields (i.e. hardness_min, hardness_max, crystal_system, ima_status, and entrytype) to it according to the needs and conditions. These additional field names are identical to the property names of geomaterial listed in the online documentation: https://github.com/smrgeoinfo/How-to-Use-Mindat-API/blob/main/geomaterialfields.csv Table 4 shows the records of data retrieval.

# %%
df<-geomaterials_contain_all_elems(c('Li','O'), hardness_min = 5.8, hardness_max = 6, crystal_system = "Triclinic",ima_status = "APPROVED",entrytype = 0)
# Out:
# List of 4
#  $ count   : int 5
#  $ next    : NULL
#  $ previous: NULL
#  $ results :List of 5
#   ..$ :List of 148
#   .. ..$ id                    : int 189
#   .. ..$ longid                : chr "1:1:189:2"
#   .. ..$ guid                  : chr "18346f06-ff73-4449-b5ca-06b0be9fe1f3"
#   .. ..$ name                  : chr "Amblygonite"
#   .. ..$ updttime              : chr "2023-05-07 19:02:19"
#   .. ..$ mindat_formula        : chr "LiAl(PO<sub>4</sub>)F"
#   .. ..$ mindat_formula_note   : chr ""
#   .. ..$ ima_formula           : chr "LiAl(PO<sub>4</sub>)F"
#   .. ..$ ima_status            :List of 2
#   .. .. ..$ : chr "APPROVED"
#   .. .. ..$ : chr "GRANDFATHERED"
#   .. ..$ ima_notes             : list()
#   .. ..$ varietyof             : int 0
#   .. ..$ synid                 : int 0
#   .. ..$ polytypeof            : int 0
#   .. ..$ groupid               : int 29268
#   .. ..$ entrytype             : int 0
#   .. ..$ entrytype_text        : chr "mineral"
#   .. ..$ description_short     : chr "Amblygonite-Montebrasite Series. Fluorine analogue of Montebrasite.\r\n\r\nOccurs chiefly in granite pegmatites"| __truncated__
#   .. ..$ impurities            : chr ""
#   .. ..$ elements              :List of 5
#   .. .. ..$ : chr "Al"
#   .. .. ..$ : chr "Li"
#   .. .. ..$ : chr "O"
#   .. .. ..$ : chr "P"
#   .. .. ..$ : chr "F"
#   .. ..$ sigelements           :List of 5
#   .. .. ..$ : chr "Al"
#   .. .. ..$ : chr "Li"
#   .. .. ..$ : chr "O"
#   .. .. ..$ : chr "P"
#   .. .. ..$ : chr "F"
#   .. ..$ tlform                : chr "Massive"
#   .. ..$ cim                   : chr "22.1.1"
#   .. ..$ occurrence            : chr "Granite pegmatite"
#   .. ..$ otheroccurrence       : chr "Zoned granite pegmatites, high-temperature tin veins, greisens."
#   .. ..$ industrial            : chr ""
#   .. ..$ discovery_year        : chr "1817"
#   .. ..$ diapheny              : chr "Transparent,Translucent"
#   .. ..$ cleavage              : chr "On {100} perfect; {110} good; <mi>{0_11}</mi>, distinct; {001}, imperfect."
#   .. ..$ parting               : chr ""
#   .. ..$ tenacity              : chr "brittle"
#   .. ..$ colour                : chr "Milk-white, yellow, beige, salmon-pink, pale green, light blue, grey; colourless in transmitted light."
#   .. ..$ csmetamict            : int 0
#   .. ..$ opticalextinction     : chr ""
#   .. ..$ hmin                  : num 5.5
#   .. ..$ hardtype              : int 0
#   .. ..$ hmax                  : num 6
#   .. ..$ vhnmin                : chr "0"
#   .. ..$ vhnmax                : chr "0"
#   .. ..$ vhnerror              : int 0
#   .. ..$ vhng                  : int 0
#   .. ..$ vhns                  : int 0
#   .. ..$ luminescence          : chr ""
#   .. ..$ lustre                : chr "Vitreous, greasy"
#   .. ..$ lustretype            : chr "Sub-Vitreous,Resinous,Greasy,Pearly"
#   .. ..$ aboutname             : chr "Named by August Breithaupt in 1817 from the Greek αμβλύς (\"amvlys\") for \"blunt\" and γωνία (\"gonia\") for \"| __truncated__
#   .. ..$ other                 : chr "Soluble with difficulty in acids. Colours a flame red.\r\n\r\nAlters to mixtures of <M>smectite</M> or <M>kaoli"| __truncated__
#   .. ..$ streak                : chr "white"
#   .. ..$ csystem               : chr "Triclinic"
#   .. ..$ cclass                : int 2
#   .. ..$ spacegroup            : int 2
#   .. ..$ a                     : chr "6.644"
#   .. ..$ b                     : chr "7.744"
#   .. ..$ c                     : chr "6.91"
#   .. ..$ alpha                 : chr "90.35"
#   .. ..$ beta                  : chr "117.33"
#   .. ..$ gamma                 : chr "91.01"
#   .. ..$ aerror                : int 0
#   .. ..$ berror                : int 0
#   .. ..$ cerror                : int 0
#   .. ..$ alphaerror            : int 0
#   .. ..$ betaerror             : int 0
#   .. ..$ gammaerror            : int 0
#   .. ..$ va3                   : num 0
#   .. ..$ z                     : int 4
#   .. ..$ dmeas                 : chr "3.04"
#   .. ..$ dmeas2                : chr "3.11"
#   .. ..$ dcalc                 : chr "3.11"
#   .. ..$ dmeaserror            : int 0
#   .. ..$ dcalcerror            : int 0
#   .. ..$ cleavagetype          : chr "Perfect"
#   .. ..$ fracturetype          : chr "Irregular/Uneven,Sub-Conchoidal"
#   .. ..$ morphology            : chr "Crude crystals, typically equant to short prismatic [010], with complex form development, to 1.5 meters; also o"| __truncated__
#   .. ..$ twinning              : chr "On <mi>{_1_11}</mi>, common, with composition plane <mi>{_1_11}</mi> with the resulting twins commonly tabular "| __truncated__
#   .. ..$ epitaxidescription    : chr ""
#   .. ..$ opticaltype           : chr "Biaxial"
#   .. ..$ opticalsign           : chr "-"
#   .. ..$ opticalalpha          : chr "1.577"
#   .. ..$ opticalbeta           : chr "1.592"
#   .. ..$ opticalgamma          : chr "1.596"
#   .. ..$ opticalomega          : chr "0"
#   .. ..$ opticalepsilon        : chr "0"
#   .. ..$ opticalalpha2         : chr "1.591"
#   .. ..$ opticalbeta2          : chr "1.605"
#   .. ..$ opticalgamma2         : chr "1.613"
#   .. ..$ opticalepsilon2       : chr "0"
#   .. ..$ opticalomega2         : chr "0"
#   .. ..$ opticaln              : chr "0"
#   .. ..$ opticaln2             : chr "0"
#   .. ..$ optical2vcalc         : chr "0"
#   .. ..$ optical2vmeasured     : chr "107"
#   .. ..$ optical2vcalc2        : chr "0"
#   .. ..$ optical2vmeasured2    : chr "129.5"
#   .. ..$ opticalalphaerror     : int 0
#   .. ..$ opticalbetaerror      : int 0
#   .. ..$ opticalgammaerror     : int 0
#   .. ..$ opticalomegaerror     : int 0
#   .. ..$ opticalepsilonerror   : int 0
#   .. ..$ opticalnerror         : int 0
#   .. ..$ optical2vcalcerror    : int 0
#   .. .. [list output truncated]
#   ..$ :List of 148
#   .. ..$ id                    : int 670
#   .. ..$ longid                : chr "1:1:670:9"
#   .. ..$ guid                  : chr "3d6a5b19-cc21-4ea7-a156-a78a85511f0f"
#   .. ..$ name                  : chr "Bikitaite"
#   .. ..$ updttime              : chr "2023-07-03 00:40:48"
#   .. ..$ mindat_formula        : chr "LiAlSi<sub>2</sub>O<sub>6</sub>&middot;H<sub>2</sub>O"
#   .. ..$ mindat_formula_note   : chr ""
#   .. ..$ ima_formula           : chr "LiAlSi<sub>2</sub>O<sub>6</sub> &middot; H<sub>2</sub>O"
#   .. ..$ ima_status            :List of 2
#   .. .. ..$ : chr "APPROVED"
#   .. .. ..$ : chr "GRANDFATHERED"
#   .. ..$ ima_notes             : list()
#   .. ..$ varietyof             : int 0
#   .. ..$ synid                 : int 0
#   .. ..$ polytypeof            : int 0
#   .. ..$ groupid               : int 4395
#   .. ..$ entrytype             : int 0
#   .. ..$ entrytype_text        : chr "mineral"
#   .. ..$ description_short     : chr "Zeolite Group."
#   .. ..$ impurities            : chr ""
#   .. ..$ elements              :List of 5
#   .. .. ..$ : chr "Al"
#   .. .. ..$ : chr "Li"
#   .. .. ..$ : chr "Si"
#   .. .. ..$ : chr "O"
#   .. .. ..$ : chr "H"
#   .. ..$ sigelements           :List of 5
#   .. .. ..$ : chr "Al"
#   .. .. ..$ : chr "Li"
#   .. .. ..$ : chr "Si"
#   .. .. ..$ : chr "O"
#   .. .. ..$ : chr "H"
#   .. ..$ tlform                : chr "colorless glassy grains"
#   .. ..$ cim                   : chr "16.1.6"
#   .. ..$ occurrence            : chr "Granite pegmatite"
#   .. ..$ otheroccurrence       : chr "Granite pegmatite"
#   .. ..$ industrial            : chr ""
#   .. ..$ discovery_year        : chr "1957"
#   .. ..$ diapheny              : chr "Transparent,Translucent"
#   .. ..$ cleavage              : chr "Perfect on the {100}, Good on the {001}"
#   .. ..$ parting               : chr ""
#   .. ..$ tenacity              : chr "brittle"
#   .. ..$ colour                : chr "Colorless, White"
#   .. ..$ csmetamict            : int 0
#   .. ..$ opticalextinction     : chr "X^c = 28°, Z=b"
#   .. ..$ hmin                  : num 6
#   .. ..$ hardtype              : int 0
#   .. ..$ hmax                  : num 6
#   .. ..$ vhnmin                : chr "0"
#   .. ..$ vhnmax                : chr "0"
#   .. ..$ vhnerror              : int 0
#   .. ..$ vhng                  : int 0
#   .. ..$ vhns                  : int 0
#   .. ..$ luminescence          : chr ""
#   .. ..$ lustre                : chr ""
#   .. ..$ lustretype            : chr "Vitreous,Sub-Vitreous"
#   .. ..$ aboutname             : chr "Named in 1957 by Cornelius Searle Hurlbut, Jr. for the type locality at Bikita, Masvingo (Fort Victoria), Masvi"| __truncated__
#   .. ..$ other                 : chr ""
#   .. ..$ streak                : chr "White"
#   .. ..$ csystem               : chr "Triclinic"
#   .. ..$ cclass                : int 1
#   .. ..$ spacegroup            : int 1
#   .. ..$ a                     : chr "8.606"
#   .. ..$ b                     : chr "4.9573"
#   .. ..$ c                     : chr "7.597"
#   .. ..$ alpha                 : chr "89.89"
#   .. ..$ beta                  : chr "114.42"
#   .. ..$ gamma                 : chr "89.96"
#   .. ..$ aerror                : int 0
#   .. ..$ berror                : int 0
#   .. ..$ cerror                : int 0
#   .. ..$ alphaerror            : int 0
#   .. ..$ betaerror             : int 0
#   .. ..$ gammaerror            : int 0
#   .. ..$ va3                   : num 295
#   .. ..$ z                     : int 1
#   .. ..$ dmeas                 : chr "2.28"
#   .. ..$ dmeas2                : chr "2.34"
#   .. ..$ dcalc                 : chr "2.3"
#   .. ..$ dmeaserror            : int 0
#   .. ..$ dcalcerror            : int 0
#   .. ..$ cleavagetype          : chr "Perfect"
#   .. ..$ fracturetype          : chr "Conchoidal"
#   .. ..$ morphology            : chr "Granular; bladed crystals are rare"
#   .. ..$ twinning              : chr ""
#   .. ..$ epitaxidescription    : chr ""
#   .. ..$ opticaltype           : chr "Biaxial"
#   .. ..$ opticalsign           : chr "-"
#   .. ..$ opticalalpha          : chr "1.510"
#   .. ..$ opticalbeta           : chr "1.521"
#   .. ..$ opticalgamma          : chr "1.523"
#   .. ..$ opticalomega          : chr "0"
#   .. ..$ opticalepsilon        : chr "0"
#   .. ..$ opticalalpha2         : chr "0"
#   .. ..$ opticalbeta2          : chr "0"
#   .. ..$ opticalgamma2         : chr "0"
#   .. ..$ opticalepsilon2       : chr "0"
#   .. ..$ opticalomega2         : chr "0"
#   .. ..$ opticaln              : chr "0"
#   .. ..$ opticaln2             : chr "0"
#   .. ..$ optical2vcalc         : chr "0"
#   .. ..$ optical2vmeasured     : chr "45"
#   .. ..$ optical2vcalc2        : chr "0"
#   .. ..$ optical2vmeasured2    : chr ""
#   .. ..$ opticalalphaerror     : int 0
#   .. ..$ opticalbetaerror      : int 0
#   .. ..$ opticalgammaerror     : int 0
#   .. ..$ opticalomegaerror     : int 0
#   .. ..$ opticalepsilonerror   : int 0
#   .. ..$ opticalnerror         : int 0
#   .. ..$ optical2vcalcerror    : int 0
#   .. .. [list output truncated]
#   ..$ :List of 148
#   .. ..$ id                    : int 2417
#   .. ..$ longid                : chr "1:1:2417:0"
#   .. ..$ guid                  : chr "2286cc6a-abb5-429a-a5dd-781d0d175ca6"
#   .. ..$ name                  : chr "Lithiomarsturite"
#   .. ..$ updttime              : chr "2022-09-01 23:58:38"
#   .. ..$ mindat_formula        : chr "LiCaMn<sub>3</sub>Si<sub>5</sub>O<sub>14</sub>(OH)"
#   .. ..$ mindat_formula_note   : chr "formerly given as LiCa<sub>2</sub>Mn<sub>2</sub>Si<sub>5</sub>O<sub>14</sub>(OH)"
#   .. ..$ ima_formula           : chr "LiCaMn<sup>2+</sup><sub>3</sub>Si<sub>5</sub>O<sub>14</sub>(OH)"
#   .. ..$ ima_status            :List of 1
#   .. .. ..$ : chr "APPROVED"
#   .. ..$ ima_notes             : list()
#   .. ..$ varietyof             : int 0
#   .. ..$ synid                 : int 0
#   .. ..$ polytypeof            : int 0
#   .. ..$ groupid               : int 0
#   .. ..$ entrytype             : int 0
#   .. ..$ entrytype_text        : chr "mineral"
#   .. ..$ description_short     : chr "The Li analogue of Marsturite."
#   .. ..$ impurities            : chr ",Fe,Mg,H2O,"
#   .. ..$ elements              :List of 6
#   .. .. ..$ : chr "Ca"
#   .. .. ..$ : chr "Li"
#   .. .. ..$ : chr "Mn"
#   .. .. ..$ : chr "Si"
#   .. .. ..$ : chr "O"
#   .. .. ..$ : chr "H"
#   .. ..$ sigelements           :List of 6
#   .. .. ..$ : chr "Ca"
#   .. .. ..$ : chr "Li"
#   .. .. ..$ : chr "Mn"
#   .. .. ..$ : chr "Si"
#   .. .. ..$ : chr "O"
#   .. .. ..$ : chr "H"
#   .. ..$ tlform                : chr "1-3 mm euhedral crystals. Usually rhombic with sharp edges that tend to be markedly lighter in color than the r"| __truncated__
#   .. ..$ cim                   : chr "14.18.26"
#   .. ..$ occurrence            : chr ""
#   .. ..$ otheroccurrence       : chr ""
#   .. ..$ industrial            : chr ""
#   .. ..$ discovery_year        : chr "1990"
#   .. ..$ diapheny              : chr "Transparent"
#   .. ..$ cleavage              : chr "good On {100} and {001}"
#   .. ..$ parting               : chr ""
#   .. ..$ tenacity              : chr "brittle"
#   .. ..$ colour                : chr "Light pinkish brown through intermediate hues to light yellow"
#   .. ..$ csmetamict            : int 0
#   .. ..$ opticalextinction     : chr ""
#   .. ..$ hmin                  : num 6
#   .. ..$ hardtype              : int 0
#   .. ..$ hmax                  : num 6
#   .. ..$ vhnmin                : chr "0"
#   .. ..$ vhnmax                : chr "0"
#   .. ..$ vhnerror              : int 0
#   .. ..$ vhng                  : int 0
#   .. ..$ vhns                  : int 0
#   .. ..$ luminescence          : chr ""
#   .. ..$ lustre                : chr ""
#   .. ..$ lustretype            : chr "Vitreous"
#   .. ..$ aboutname             : chr "Named for being the lithium analogue of marsturite.  The root marsturite is for Marion Butler Stuart [December "| __truncated__
#   .. ..$ other                 : chr ""
#   .. ..$ streak                : chr "Very light brown"
#   .. ..$ csystem               : chr "Triclinic"
#   .. ..$ cclass                : int 2
#   .. ..$ spacegroup            : int 2
#   .. ..$ a                     : chr "7.652"
#   .. ..$ b                     : chr "12.119"
#   .. ..$ c                     : chr "6.805"
#   .. ..$ alpha                 : chr "85.41"
#   .. ..$ beta                  : chr "94.42"
#   .. ..$ gamma                 : chr "111.51"
#   .. ..$ aerror                : int 3
#   .. ..$ berror                : int 3
#   .. ..$ cerror                : int 2
#   .. ..$ alphaerror            : int 2
#   .. ..$ betaerror             : int 3
#   .. ..$ gammaerror            : int 2
#   .. ..$ va3                   : num 0
#   .. ..$ z                     : int 2
#   .. ..$ dmeas                 : chr "3.32"
#   .. ..$ dmeas2                : chr "3.32"
#   .. ..$ dcalc                 : chr "3.27"
#   .. ..$ dmeaserror            : int 0
#   .. ..$ dcalcerror            : int 0
#   .. ..$ cleavagetype          : chr "Distinct/Good"
#   .. ..$ fracturetype          : chr ""
#   .. ..$ morphology            : chr "{100} (dominant), {010}, and {001}."
#   .. ..$ twinning              : chr ""
#   .. ..$ epitaxidescription    : chr ""
#   .. ..$ opticaltype           : chr "Biaxial"
#   .. ..$ opticalsign           : chr "-"
#   .. ..$ opticalalpha          : chr "1.645"
#   .. ..$ opticalbeta           : chr "1.660"
#   .. ..$ opticalgamma          : chr "1.666"
#   .. ..$ opticalomega          : chr "0"
#   .. ..$ opticalepsilon        : chr "0"
#   .. ..$ opticalalpha2         : chr "0"
#   .. ..$ opticalbeta2          : chr "0"
#   .. ..$ opticalgamma2         : chr "0"
#   .. ..$ opticalepsilon2       : chr "0"
#   .. ..$ opticalomega2         : chr "0"
#   .. ..$ opticaln              : chr "0"
#   .. ..$ opticaln2             : chr "0"
#   .. ..$ optical2vcalc         : chr "64"
#   .. ..$ optical2vmeasured     : chr "59"
#   .. ..$ optical2vcalc2        : chr "0"
#   .. ..$ optical2vmeasured2    : chr ""
#   .. ..$ opticalalphaerror     : int 1
#   .. ..$ opticalbetaerror      : int 1
#   .. ..$ opticalgammaerror     : int 1
#   .. ..$ opticalomegaerror     : int 0
#   .. ..$ opticalepsilonerror   : int 0
#   .. ..$ opticalnerror         : int 0
#   .. ..$ optical2vcalcerror    : int 0
#   .. .. [list output truncated]
#   ..$ :List of 148
#   .. ..$ id                    : int 2763
#   .. ..$ longid                : chr "1:1:2763:8"
#   .. ..$ guid                  : chr "2fcb7a59-3a59-4a73-9263-e8e9be9d45e8"
#   .. ..$ name                  : chr "Montebrasite"
#   .. ..$ updttime              : chr "2020-07-05 09:47:58"
#   .. ..$ mindat_formula        : chr "LiAl(PO<sub>4</sub>)(OH)"
#   .. ..$ mindat_formula_note   : chr ""
#   .. ..$ ima_formula           : chr "LiAl(PO<sub>4</sub>)(OH)"
#   .. ..$ ima_status            :List of 2
#   .. .. ..$ : chr "APPROVED"
#   .. .. ..$ : chr "GRANDFATHERED"
#   .. ..$ ima_notes             : list()
#   .. ..$ varietyof             : int 0
#   .. ..$ synid                 : int 0
#   .. ..$ polytypeof            : int 0
#   .. ..$ groupid               : int 29268
#   .. ..$ entrytype             : int 0
#   .. ..$ entrytype_text        : chr "mineral"
#   .. ..$ description_short     : chr "Amblygonite-Montebrasite Series. The hydroxyl analogue of Amblygonite.\r\nMontebrasite is, by far, the most com"| __truncated__
#   .. ..$ impurities            : chr ",Na,,"
#   .. ..$ elements              :List of 5
#   .. .. ..$ : chr "Al"
#   .. .. ..$ : chr "Li"
#   .. .. ..$ : chr "O"
#   .. .. ..$ : chr "P"
#   .. .. ..$ : chr "H"
#   .. ..$ sigelements           :List of 5
#   .. .. ..$ : chr "Al"
#   .. .. ..$ : chr "Li"
#   .. .. ..$ : chr "O"
#   .. .. ..$ : chr "P"
#   .. .. ..$ : chr "H"
#   .. ..$ tlform                : chr ""
#   .. ..$ cim                   : chr "19.8.1"
#   .. ..$ occurrence            : chr "Granite pegmatite"
#   .. ..$ otheroccurrence       : chr "A late primary mineral in zoned, complex granitic pegmatites."
#   .. ..$ industrial            : chr "Previously used as an ore of lithium."
#   .. ..$ discovery_year        : chr "1870"
#   .. ..$ diapheny              : chr "Transparent,Translucent"
#   .. ..$ cleavage              : chr "Perfect on {100}, good on {110}, distinct on <mi>{0_11}</mi>, and on {001}, imperfect."
#   .. ..$ parting               : chr ""
#   .. ..$ tenacity              : chr "brittle"
#   .. ..$ colour                : chr " White, colorless, gray white, very pale brown, pale pink, pale yellow"
#   .. ..$ csmetamict            : int 0
#   .. ..$ opticalextinction     : chr ""
#   .. ..$ hmin                  : num 5.5
#   .. ..$ hardtype              : int 0
#   .. ..$ hmax                  : num 6
#   .. ..$ vhnmin                : chr "0"
#   .. ..$ vhnmax                : chr "0"
#   .. ..$ vhnerror              : int 0
#   .. ..$ vhng                  : int 0
#   .. ..$ vhns                  : int 0
#   .. ..$ luminescence          : chr ""
#   .. ..$ lustre                : chr ""
#   .. ..$ lustretype            : chr "Sub-Vitreous,Resinous,Greasy,Pearly"
#   .. ..$ aboutname             : chr "Named by Alfred Des Cloizeaux in 1871 for the type locality, the Montebras Mine, Montebras-en-Soumans, Boussac,"| __truncated__
#   .. ..$ other                 : chr "Soluble with difficulty in acids. Colours a flame red.\r\n\r\nMay alter to mixtures of <M>smectite</M> or <M>ka"| __truncated__
#   .. ..$ streak                : chr "White"
#   .. ..$ csystem               : chr "Triclinic"
#   .. ..$ cclass                : int 2
#   .. ..$ spacegroup            : int 2
#   .. ..$ a                     : chr "6.713"
#   .. ..$ b                     : chr "7.708"
#   .. ..$ c                     : chr "7.0194"
#   .. ..$ alpha                 : chr "91.31"
#   .. ..$ beta                  : chr "117.93"
#   .. ..$ gamma                 : chr "91.77"
#   .. ..$ aerror                : int 1
#   .. ..$ berror                : int 1
#   .. ..$ cerror                : int 7
#   .. ..$ alphaerror            : int 1
#   .. ..$ betaerror             : int 1
#   .. ..$ gammaerror            : int 1
#   .. ..$ va3                   : num 0
#   .. ..$ z                     : int 4
#   .. ..$ dmeas                 : chr "2.98"
#   .. ..$ dmeas2                : chr "3.04"
#   .. ..$ dcalc                 : chr "3.03"
#   .. ..$ dmeaserror            : int 0
#   .. ..$ dcalcerror            : int 0
#   .. ..$ cleavagetype          : chr "Perfect"
#   .. ..$ fracturetype          : chr "Irregular/Uneven,Sub-Conchoidal"
#   .. ..$ morphology            : chr "Crude blocky crystals, typically equant to short prismatic [010], with complex form development, to 1.5 meters;"| __truncated__
#   .. ..$ twinning              : chr "On <mi>{_1_11}</mi>, common, with composition plane <mi>{_1_11}</mi> with the resulting twins commonly tabular "| __truncated__
#   .. ..$ epitaxidescription    : chr ""
#   .. ..$ opticaltype           : chr "Biaxial"
#   .. ..$ opticalsign           : chr "+/-"
#   .. ..$ opticalalpha          : chr "1.594"
#   .. ..$ opticalbeta           : chr "1.608"
#   .. ..$ opticalgamma          : chr "1.616"
#   .. ..$ opticalomega          : chr "0"
#   .. ..$ opticalepsilon        : chr "0"
#   .. ..$ opticalalpha2         : chr "1.615"
#   .. ..$ opticalbeta2          : chr "1.624"
#   .. ..$ opticalgamma2         : chr "1.645"
#   .. ..$ opticalepsilon2       : chr "0"
#   .. ..$ opticalomega2         : chr "0"
#   .. ..$ opticaln              : chr "0"
#   .. ..$ opticaln2             : chr "0"
#   .. ..$ optical2vcalc         : chr "52"
#   .. ..$ optical2vmeasured     : chr "66"
#   .. ..$ optical2vcalc2        : chr "88"
#   .. ..$ optical2vmeasured2    : chr "101"
#   .. ..$ opticalalphaerror     : int 0
#   .. ..$ opticalbetaerror      : int 0
#   .. ..$ opticalgammaerror     : int 0
#   .. ..$ opticalomegaerror     : int 0
#   .. ..$ opticalepsilonerror   : int 0
#   .. ..$ opticalnerror         : int 0
#   .. ..$ optical2vcalcerror    : int 0
#   .. .. [list output truncated]
#   ..$ :List of 148
#   .. ..$ id                    : int 2859
#   .. ..$ longid                : chr "1:1:2859:8"
#   .. ..$ guid                  : chr "de8a8cc2-6f14-4c7c-a486-c47829544b50"
#   .. ..$ name                  : chr "Natronambulite"
#   .. ..$ updttime              : chr "2022-10-27 00:59:08"
#   .. ..$ mindat_formula        : chr "(Na,Li)(Mn,Ca)<sub>4</sub>Si<sub>5</sub>O<sub>14</sub>OH"
#   .. ..$ mindat_formula_note   : chr ""
#   .. ..$ ima_formula           : chr "NaMn<sup>2+</sup><sub>4</sub>Si<sub>5</sub>O<sub>14</sub>(OH)"
#   .. ..$ ima_status            :List of 1
#   .. .. ..$ : chr "APPROVED"
#   .. ..$ ima_notes             : list()
#   .. ..$ varietyof             : int 0
#   .. ..$ synid                 : int 0
#   .. ..$ polytypeof            : int 0
#   .. ..$ groupid               : int 0
#   .. ..$ entrytype             : int 0
#   .. ..$ entrytype_text        : chr "mineral"
#   .. ..$ description_short     : chr "Nambulite-Natronambulite Series.\r\n\r\nThe Na analogue of Nambulite."
#   .. ..$ impurities            : chr ",Fe,Mg,Ca,H2O,"
#   .. ..$ elements              :List of 7
#   .. .. ..$ : chr "Ca"
#   .. .. ..$ : chr "Li"
#   .. .. ..$ : chr "Mn"
#   .. .. ..$ : chr "Na"
#   .. .. ..$ : chr "Si"
#   .. .. ..$ : chr "O"
#   .. .. ..$ : chr "H"
#   .. ..$ sigelements           :List of 5
#   .. .. ..$ : chr "Mn"
#   .. .. ..$ : chr "Na"
#   .. .. ..$ : chr "Si"
#   .. .. ..$ : chr "O"
#   .. .. ..$ : chr "H"
#   .. ..$ tlform                : chr "Bands of grains to 7 mm in size."
#   .. ..$ cim                   : chr "14.18.2"
#   .. ..$ occurrence            : chr "Contact metamorphosed bedded manganese ore deposits."
#   .. ..$ otheroccurrence       : chr ""
#   .. ..$ industrial            : chr ""
#   .. ..$ discovery_year        : chr "1985"
#   .. ..$ diapheny              : chr ""
#   .. ..$ cleavage              : chr "[100] and [100] perfect"
#   .. ..$ parting               : chr ""
#   .. ..$ tenacity              : chr ""
#   .. ..$ colour                : chr "Pinkish orange"
#   .. ..$ csmetamict            : int 0
#   .. ..$ opticalextinction     : chr ""
#   .. ..$ hmin                  : num 5.5
#   .. ..$ hardtype              : int 0
#   .. ..$ hmax                  : num 6
#   .. ..$ vhnmin                : chr "0"
#   .. ..$ vhnmax                : chr "0"
#   .. ..$ vhnerror              : int 0
#   .. ..$ vhng                  : int 0
#   .. ..$ vhns                  : int 0
#   .. ..$ luminescence          : chr ""
#   .. ..$ lustre                : chr ""
#   .. ..$ lustretype            : chr "Vitreous"
#   .. ..$ aboutname             : chr "Named for its relation to nambulite, with dominant sodium, NATRium in Latin."
#   .. ..$ other                 : chr ""
#   .. ..$ streak                : chr "White with very faint orange tint"
#   .. ..$ csystem               : chr "Triclinic"
#   .. ..$ cclass                : int 0
#   .. ..$ spacegroup            : int 0
#   .. ..$ a                     : chr "7.62"
#   .. ..$ b                     : chr "11.76"
#   .. ..$ c                     : chr "6.73"
#   .. ..$ alpha                 : chr "92.81"
#   .. ..$ beta                  : chr "94.55"
#   .. ..$ gamma                 : chr "106.87"
#   .. ..$ aerror                : int 0
#   .. ..$ berror                : int 0
#   .. ..$ cerror                : int 0
#   .. ..$ alphaerror            : int 0
#   .. ..$ betaerror             : int 0
#   .. ..$ gammaerror            : int 0
#   .. ..$ va3                   : num 0
#   .. ..$ z                     : int 0
#   .. ..$ dmeas                 : chr "3.51"
#   .. ..$ dmeas2                : chr "3.51"
#   .. ..$ dcalc                 : chr "3.50"
#   .. ..$ dmeaserror            : int 0
#   .. ..$ dcalcerror            : int 0
#   .. ..$ cleavagetype          : chr "Perfect"
#   .. ..$ fracturetype          : chr ""
#   .. ..$ morphology            : chr ""
#   .. ..$ twinning              : chr ""
#   .. ..$ epitaxidescription    : chr ""
#   .. ..$ opticaltype           : chr "Biaxial"
#   .. ..$ opticalsign           : chr "+"
#   .. ..$ opticalalpha          : chr "1.706"
#   .. ..$ opticalbeta           : chr "1.71"
#   .. ..$ opticalgamma          : chr "1.73"
#   .. ..$ opticalomega          : chr "0"
#   .. ..$ opticalepsilon        : chr "0"
#   .. ..$ opticalalpha2         : chr "0"
#   .. ..$ opticalbeta2          : chr "0"
#   .. ..$ opticalgamma2         : chr "0"
#   .. ..$ opticalepsilon2       : chr "0"
#   .. ..$ opticalomega2         : chr "0"
#   .. ..$ opticaln              : chr "0"
#   .. ..$ opticaln2             : chr "0"
#   .. ..$ optical2vcalc         : chr "50"
#   .. ..$ optical2vmeasured     : chr "45"
#   .. ..$ optical2vcalc2        : chr "0"
#   .. ..$ optical2vmeasured2    : chr "0"
#   .. ..$ opticalalphaerror     : int 0
#   .. ..$ opticalbetaerror      : int 0
#   .. ..$ opticalgammaerror     : int 0
#   .. ..$ opticalomegaerror     : int 0
#   .. ..$ opticalepsilonerror   : int 0
#   .. ..$ opticalnerror         : int 0
#   .. ..$ optical2vcalcerror    : int 0
#   .. .. [list output truncated]

# %%
df
# Out:
#   id   longid     guid                                 name
# 1  189 1:1:189:2  18346f06-ff73-4449-b5ca-06b0be9fe1f3 Amblygonite
# 2  670 1:1:670:9  3d6a5b19-cc21-4ea7-a156-a78a85511f0f Bikitaite
# 3 2417 1:1:2417:0 2286cc6a-abb5-429a-a5dd-781d0d175ca6 Lithiomarsturite
# 4 2763 1:1:2763:8 2fcb7a59-3a59-4a73-9263-e8e9be9d45e8 Montebrasite
# 5 2859 1:1:2859:8 de8a8cc2-6f14-4c7c-a486-c47829544b50 Natronambulite
#   updttime            mindat_formula
# 1 2023-05-07 19:02:19 LiAl(PO<sub>4</sub>)F
# 2 2023-07-03 00:40:48 LiAlSi<sub>2</sub>O<sub>6</sub>&middot;H<sub>2</sub>O
# 3 2022-09-01 23:58:38 LiCaMn<sub>3</sub>Si<sub>5</sub>O<sub>14</sub>(OH)
# 4 2020-07-05 09:47:58 LiAl(PO<sub>4</sub>)(OH)
# 5 2022-10-27 00:59:08 (Na,Li)(Mn,Ca)<sub>4</sub>Si<sub>5</sub>O<sub>14</sub>OH
#   mindat_formula_note
# 1
# 2
# 3 formerly given as LiCa<sub>2</sub>Mn<sub>2</sub>Si<sub>5</sub>O<sub>14</sub>(OH)
# 4
# 5
#   ima_formula
# 1 LiAl(PO<sub>4</sub>)F
# 2 LiAlSi<sub>2</sub>O<sub>6</sub> &middot; H<sub>2</sub>O
# 3 LiCaMn<sup>2+</sup><sub>3</sub>Si<sub>5</sub>O<sub>14</sub>(OH)
# 4 LiAl(PO<sub>4</sub>)(OH)
# 5 NaMn<sup>2+</sup><sub>4</sub>Si<sub>5</sub>O<sub>14</sub>(OH)
#   ima_status                   ima_notes ⋯ rock_parent rock_parent2 rock_root
# 1 APPROVED     , GRANDFATHERED NULL      ⋯ 0           0            0
# 2 APPROVED     , GRANDFATHERED NULL      ⋯ 0           0            0
# 3 APPROVED                     NULL      ⋯ 0           0            0
# 4 APPROVED     , GRANDFATHERED NULL      ⋯ 0           0            0
# 5 APPROVED                     NULL      ⋯ 0           0            0
#   rock_bgs_code meteoritical_code key_elements shortcode_ima rimin rimax
# 1                                 Li           Aby           1.591 1.613
# 2                                 Li           Bik
# 3                                 Li           Lmsr
# 4                                 Li           Mbs           1.615 1.645
# 5                                              Nnbl
#   weighting
# 1  543
# 2  302
# 3   41
# 4 1809
# 5   23
