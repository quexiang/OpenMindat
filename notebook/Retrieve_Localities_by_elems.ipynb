# %%
library(httr)
library(jsonlite)
library (OpenMindat)

# %%
#Please replace the following string “9ce67655d74bcd981e937be80dcea9cb” by your own Mindat token.
mindat_connection("9ce67655d74bcd981e937be80dcea9cb",page_size = 1500)

# %%
df1<-localities_list_elems_exc(c("H", "O", "Si", "Al", "Fe", "Ca", "Na", "K", "P", "C", "Mn", "F", "Mg", "S"),fields = "id,country,elements,latitude,longitude,level,Txt")
# Out:
# List of 3
#  $ next    : chr "https://api.mindat.org/localities/?cursor=cD0yMjQ4Mw%3D%3D&elements_exc=H%2CO%2CSi%2CAl%2CFe%2CCa%2CNa%2CK%2CP%"| __truncated__
#  $ previous: NULL
#  $ results :List of 1500
#   ..$ :List of 6
#   .. ..$ id       : int 104
#   .. ..$ latitude : num -30.2
#   .. ..$ longitude: num 152
#   .. ..$ elements : chr "-Au-"
#   .. ..$ country  : chr "Australia"
#   .. ..$ level    : int 4
#   ..$ :List of 6
#   .. ..$ id       : int 180
#   .. ..$ latitude : num 0
#   .. ..$ longitude: num 0
#   .. ..$ elements : chr "-"
#   .. ..$ country  : chr ""
#   .. ..$ level    : int 0
#   ..$ :List of 6
#   .. ..$ id       : int 182
#   .. ..$ latitude : num 0
#   .. ..$ longitude: num 0
#   .. ..$ elements : chr "-"
#   .. ..$ country  : chr ""
#   .. ..$ level    : int 0
#   ..$ :List of 6
#   .. ..$ id       : int 194
#   .. ..$ latitude : num 0
#   .. ..$ longitude: num 0
#   .. ..$ elements : chr "-"
#   .. ..$ country  : chr ""
#   .. ..$ level    : int 0
# ...

# %%
df1
# Out:
#        id     latitude  longitude   elements        country        level
# 1       104   -30.23207 151.877907  -Au-            Australia      4
# 2       180     0.00000   0.000000  -                              0
# 3       182     0.00000   0.000000  -                              0
# 4       194     0.00000   0.000000  -                              0
# 5       214   -36.58893 143.244155  -Ag-Cl-         Australia      4
# 6       372     0.00000   0.000000  -                              0
# 7       413     0.00000   0.000000                                 0
# 8       462     0.00000   0.000000  -Pt-Ir-         Myanmar        4
# 9       665   -30.03410 -70.917800  -As-Cu-Ag-Cl-I- Chile          6
# 10      718     0.00000   0.000000  -                              0
# 11      741     0.00000   0.000000  -Au-Pt-         Colombia       3
# 12      748    45.47931  14.574338  -               Croatia        1
# 13      765    50.33389  12.776111  -               Czech Republic 4
# ...

# %%
df2<-localities_list_elems_inc(c("Dy"))
# Out:
# List of 3
#  $ next    : NULL
#  $ previous: NULL
#  $ results :List of 9
#   ..$ :List of 37
#   .. ..$ id                 : int 1763
#   .. ..$ longid             : chr "1:2:1763:6"
#   .. ..$ guid               : chr "01893b44-b9b4-4252-a1a3-45d3fac80cef"
#   .. ..$ txt                : chr "Baden-Württemberg, Germany"
#   .. ..$ revtxtd            : chr "Germany, Baden-Württemberg"
#   .. ..$ description_short  : chr "Baden-Württemberg is a state in southwest Germany, east of the Rhine, which forms the southern sector of German"| __truncated__
#   .. ..$ latitude           : num 0
#   .. ..$ longitude          : num 0
#   .. ..$ langtxt            : chr "Baden-Württemberg, Deutschland"
#   .. ..$ dateadd            : chr "1980-01-01 00:00:00"
#   .. ..$ datemodify         : chr "2021-07-14 09:30:02"
#   .. ..$ elements           : chr "-As-O-K-H-U-Ag-S-Ca-Fe-Mg-Si-Zn-Al-Na-Cu-Nd-Y-Ce-Dy-La-Bi-Pb-Cl-Sb-Co-N-Ti-C-Ni-Be-Sr-Ba-Ge-F-Mn-Au-P-Zr-V-Se-B"| __truncated__
# ...

# %%
df2
# Out:
#   id     longid       guid
# 1   1763 1:2:1763:6   01893b44-b9b4-4252-a1a3-45d3fac80cef
# 2   1777 1:2:1777:3   e57c12c2-2e3b-46bd-934a-abb134c2aaac
# 3   4434 1:2:4434:2   ca85a25f-b7f7-4541-9835-115aeac9b240
# 4  13883 1:2:13883:8  24bddfde-e125-40b8-a5c5-33362bda47e9
# 5  14244 1:2:14244:2
# 6  33286 1:2:33286:9  e1be4946-d14e-47c8-ae3e-58599f1fae39
# 7 289456 1:2:289456:3
# 8 310035 1:2:310035:9 1fc0ee13-8a00-45e7-b51e-4ef8a934e183
# 9 337757 1:2:337757:7 3ee1e593-eb94-4604-95be-a3fa1038152f
#   txt
# 1 Baden-Württemberg, Germany
# 2 Krunkelbach Valley Uranium deposit, Menzenschwand, St Blasien, Waldshut, Freiburg Region, Baden-Württemberg, Germany
# 3 Black Forest, Baden-Württemberg, Germany
# 4 Wittichen, Schenkenzell, Rottweil, Freiburg Region, Baden-Württemberg, Germany
# 5 Germany
# 6 Schenkenzell, Rottweil, Freiburg Region, Baden-Württemberg, Germany
# 7 Earth
# 8 Freiburg Region, Baden-Württemberg, Germany
# 9 Rottweil, Freiburg Region, Baden-Württemberg, Germany
# ...

# %%
df3<-localities_list_elems_inc_exc(c("Dy"), c("Li"))
# Out:
# List of 3
#  $ next    : NULL
#  $ previous: NULL
#  $ results :List of 3
#   ..$ :List of 37
#   .. ..$ id                 : int 13883
#   .. ..$ longid             : chr "1:2:13883:8"
#   .. ..$ guid               : chr "24bddfde-e125-40b8-a5c5-33362bda47e9"
#   .. ..$ txt                : chr "Wittichen, Schenkenzell, Rottweil, Freiburg Region, Baden-Württemberg, Germany"
#   .. ..$ revtxtd            : chr "Germany, Baden-Württemberg, Freiburg Region, Rottweil, Schenkenzell, Wittichen"
#   .. ..$ description_short  : chr "A famous old Bi-Co-Ni-Ag-U mining district centred on the village of Wittichen in the Black Forest. Hydrotherma"| __truncated__
#   .. ..$ latitude           : num 48.3
#   .. ..$ longitude          : num 8.34
#   .. ..$ langtxt            : chr "Wittichen, Schenkenzell, Schwarzwald, Baden-Württemberg, Deutschland"
#   .. ..$ dateadd            : chr "2002-11-10 04:02:00"
#   .. ..$ datemodify         : chr "2023-11-04 10:04:44"
# ...

# %%
df3
# Out:
#   id     longid       guid
# 1  13883 1:2:13883:8  24bddfde-e125-40b8-a5c5-33362bda47e9
# 2  33286 1:2:33286:9  e1be4946-d14e-47c8-ae3e-58599f1fae39
# 3 337757 1:2:337757:7 3ee1e593-eb94-4604-95be-a3fa1038152f
#   txt
# 1 Wittichen, Schenkenzell, Rottweil, Freiburg Region, Baden-Württemberg, Germany
# 2 Schenkenzell, Rottweil, Freiburg Region, Baden-Württemberg, Germany
# 3 Rottweil, Freiburg Region, Baden-Württemberg, Germany
#   revtxtd
# 1 Germany, Baden-Württemberg, Freiburg Region, Rottweil, Schenkenzell, Wittichen
# 2 Germany, Baden-Württemberg, Freiburg Region, Rottweil, Schenkenzell
# 3 Germany, Baden-Württemberg, Freiburg Region, Rottweil
#   description_short
# 1 A famous old Bi-Co-Ni-Ag-U mining district centred on the village of Wittichen in the Black Forest. Hydrothermal veins are hosted in granite.
# 2
# 3
#   latitude longitude
# 1 48.33811 8.34343
# 2  0.00000 0.00000
# 3  0.00000 0.00000
#   langtxt
# ...

# %%
df4<-locality_age_list()
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
df4
# Out:
#       age_id age_mav  age_pmv age_ma2v age_pm2v
# 1      4     1250.000   0.000  980.00    0.000
# 2      3      170.300   1.400  157.30    1.000
# 3      5     4000.000 200.000 4000.00  200.000
# 4      6     4100.000   0.000 3800.00    0.000
# 5      7      870.000   0.000  550.00    0.000
# 6      8     1300.000   0.000  900.00    0.000
# 7      9      750.000   0.000  633.00    0.000
# 8     10      541.000   0.000  513.00    3.000
# 9     11       66.000   0.000   66.00    0.000
# 10    12     2023.000   0.004 2023.00    0.004
# 11    13     1850.000   3.000 1850.00    3.000
# 12    14     2125.000 125.000 1780.00   70.000
# 13    15     1425.000  75.000 1250.00   50.000
# 14    16      550.000   0.000  500.00    0.000
# 15    17     4574.700   6.000 4574.70    6.000
# 16    18      260.000   0.000  225.00    0.000
# 17    19     3500.000   0.000  850.00    0.000
# 18    20      550.000   0.000  495.00    0.000
# 19    21     1400.000   0.000 1000.00    0.000
# ...

# %%
df5<-locality_age(id = 60)
# Out:
# List of 14
#  $ age_id      : int 60
#  $ age_mav     : num 717
#  $ age_pmv     : num 0.1
#  $ age_ma2v    : num 660
#  $ age_pm2v    : num 0
#  $ agemethod   : chr "Re-Os"
#  $ agereference: chr " Rooney, A. D.; Strauss, J. V.; Brandon, A. D.; Macdonald, F. A. (2015). \"A Cryogenian chronology: Two long-la"| __truncated__
#  $ age_ma      : chr "717.4"
#  $ age_pm      : chr "0.1"
#  $ age_ma2     : chr "~660"
#  $ age_pm2     : chr ""
#  $ ages1       : int 0
#  $ ages2       : int 0
#  $ age_type    : int 2

# %%
df5
# Out:
#   age_id age_mav age_pmv age_ma2v age_pm2v agemethod
# 1 60     717.4   0.1     660      0        Re-Os
#   agereference
# 1  Rooney, A. D.; Strauss, J. V.; Brandon, A. D.; Macdonald, F. A. (2015). "A Cryogenian chronology: Two long-lasting synchronous Neoproterozoic glaciations". Geology. 43: 459
#   age_ma age_pm age_ma2 age_pm2 ages1 ages2 age_type
# 1 717.4  0.1    ~660            0     0     2
